# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
from dotenv import load_dotenv
project_root = os.path.abspath("..")
sys.path.insert(0, project_root)

# %%
load_dotenv()
BASE_PATH = os.getenv("BASE_PATH")
df = pd.read_parquet(f"{BASE_PATH}/data/processed/clean_delivery_time.parquet")
df.head()
# Out:
#    Distance_m Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0      7930.0   Windy           Low   Afternoon      Scooter
# 1     16420.0   Clear        Medium     Evening         Bike
# 2      9520.0   Foggy           Low       Night      Scooter
# 3      7440.0   Rainy        Medium   Afternoon      Scooter
# 4     19030.0   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                       1                 43
# 1                    20                       2                 84
# 2                    28                       1                 59
# 3                     5                       1                 37
# 4                    16                       5                 68

# %%
df[['Distance_m', 'Delivery_Time_min']].corr()
# Out:
#                    Distance_m  Delivery_Time_min
# Distance_m           1.000000           0.780998
# Delivery_Time_min    0.780998           1.000000

# %%
numeric_features = ['Distance_m', 'Preparation_Time_min', 'Courier_Experience_yrs']

for col in numeric_features:
    sns.scatterplot(data=df, x=col, y='Delivery_Time_min')
    plt.title(col)
    plt.show()

# %%
categorical_features = ['Weather', 'Traffic_Level', 'Time_of_Day', 'Vehicle_Type']

for col in categorical_features:
    sns.boxplot(data=df, x=col, y='Delivery_Time_min')
    plt.title(col)
    plt.show()

# %%
numeric_cols = ['Distance_m', 'Preparation_Time_min', 'Courier_Experience_yrs', 'Delivery_Time_min']
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
